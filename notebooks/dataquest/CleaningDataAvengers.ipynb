# %% [markdown]
# # Cleaning Up Data about Avengers
#
# Corresponds to DataQuest challenge.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
from pathlib import Path

# %%
data_path = Path.home() / "datasets" / "tabular_practice"

avengers = pd.read_csv(data_path / "avengers.csv", encoding="ISO-8859-1")
avengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          173 non-null    object
#  1   Name/Alias                   163 non-null    object
#  2   Appearances                  173 non-null    int64
#  3   Current?                     173 non-null    object
#  4   Gender                       173 non-null    object
#  5   Probationary Introl          15 non-null     object
#  6   Full/Reserve Avengers Intro  159 non-null    object
#  7   Year                         173 non-null    int64
#  8   Years since joining          173 non-null    int64
#  9   Honorary                     173 non-null    object
#  10  Death1                       173 non-null    object
#  11  Return1                      69 non-null     object
#  12  Death2                       17 non-null     object
#  13  Return2                      16 non-null     object
#  14  Death3                       2 non-null      object
#  15  Return3                      2 non-null      object
#  16  Death4                       1 non-null      object
#  17  Return4                      1 non-null      object
#  18  Death5                       1 non-null      object
#  19  Return5                      1 non-null      object
#  20  Notes                        75 non-null     object
# dtypes: int64(3), object(18)
# memory usage: 28.5+ KB

# %% [markdown]
# Description of columns:
#
# * "URL":	The URL of the comic character on the Marvel Wikia
# * "Name/Alias":	The full name or alias of the character
# * "Appearances":	The number of comic books that character appeared in as of April 30
# * "Current?":	Is the member currently active on an avengers affiliated team?
# * "Gender":	The recorded gender of the character
# * "Probationary":	Sometimes the character was given probationary status as an Avenger, this is the date that happened
# * "Full/Reserve":	The month and year the character was introduced as a full or reserve member of the Avengers
# * "Year":	The year the character was introduced as a full or reserve member of the Avengers
# * "Years since joining":	2015 minus the year
# * "Honorary":	The status of the avenger, if they were given "Honorary" Avenger status, if they are simply in the "Academy," or "Full" otherwise
# * "Death1":	Yes if the Avenger died, No if not.
# * "Return1":	Yes if the Avenger returned from their first death, No if they did not, blank if not applicable
# * "Death2":	Yes if the Avenger died a second time after their revival, No if they did not, blank if not applicable
# * "Return2":	Yes if the Avenger returned from their second death, No if they did not, blank if not applicable
# * "Death3":	Yes if the Avenger died a third time after their second revival, No if they did not, blank if not applicable
# * "Return3":	Yes if the Avenger returned from their third death, No if they did not, blank if not applicable
# * "Death4":	Yes if the Avenger died a fourth time after their third revival, No if they did not, blank if not applicable
# * "Return4":	Yes if the Avenger returned from their fourth death, No if they did not, blank if not applicable
# * "Death5":	Yes if the Avenger died a fifth time after their fourth revival, No if they did not, blank if not applicable
# * "Return5":	Yes if the Avenger returned from their fifth death, No if they did not, blank if not applicable
# * "Notes":	Descriptions of deaths and resurrections.

# %%
avengers.describe(include="all")
# Out:
#                                                   URL      Name/Alias  \
# count                                             173             163
# unique                                            173             162
# top     http://marvel.wikia.com/Henry_Pym_(Earth-616)  Vance Astrovik
# freq                                                1               2
# mean                                              NaN             NaN
# std                                               NaN             NaN
# min                                               NaN             NaN
# 25%                                               NaN             NaN
# 50%                                               NaN             NaN
# 75%                                               NaN             NaN
# max                                               NaN             NaN
#
#         Appearances Current? Gender Probationary Introl  \
# count    173.000000      173    173                  15
# unique          NaN        2      2                  12
# top             NaN       NO   MALE              Jul-75
# freq            NaN       91    115                   2
# mean     414.052023      NaN    NaN                 NaN
# std      677.991950      NaN    NaN                 NaN
# min        2.000000      NaN    NaN                 NaN
# 25%       58.000000      NaN    NaN                 NaN
# 50%      132.000000      NaN    NaN                 NaN
# 75%      491.000000      NaN    NaN                 NaN
# max     4333.000000      NaN    NaN                 NaN
#
#        Full/Reserve Avengers Intro         Year  Years since joining Honorary  \
# count                          159   173.000000           173.000000      173
# unique                          93          NaN                  NaN        4
# top                         Sep-63          NaN                  NaN     Full
# freq                             6          NaN                  NaN      138
# mean                           NaN  1988.445087            26.554913      NaN
# std                            NaN    30.374669            30.374669      NaN
# min                            NaN  1900.000000             0.000000      NaN
# 25%                            NaN  1979.000000             5.000000      NaN
# 50%                            NaN  1996.000000            19.000000      NaN
# 75%                            NaN  2010.000000            36.000000      NaN
# max                            NaN  2015.000000           115.000000      NaN
#
#         ... Return1 Death2 Return2 Death3 Return3 Death4 Return4 Death5  \
# count   ...      69     17      16      2       2      1       1      1
# unique  ...       2      2       2      1       2      1       1      1
# top     ...     YES    YES      NO    YES      NO    YES     YES    YES
# freq    ...      46     16       8      2       1      1       1      1
# mean    ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# std     ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# min     ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 25%     ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 50%     ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 75%     ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# max     ...     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN
#
#        Return5                          Notes
# count        1                             75
# unique       1                             71
# top        YES  Died in New_Avengers_Vol_3_32
# freq         1                              4
# mean       NaN                            NaN
# std        NaN                            NaN
# min        NaN                            NaN
# 25%        NaN                            NaN
# 50%        NaN                            NaN
# 75%        NaN                            NaN
# max        NaN                            NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# First, we replace column names by more manageable expressions.

# %%
new_columns = list(avengers.columns.str.lower().str.strip().str.replace(" ", "_").str.replace("/", "_"))
new_columns
# Out:
# ['url',
#  'name_alias',
#  'appearances',
#  'current?',
#  'gender',
#  'probationary_introl',
#  'full_reserve_avengers_intro',
#  'year',
#  'years_since_joining',
#  'honorary',
#  'death1',
#  'return1',
#  'death2',
#  'return2',
#  'death3',
#  'return3',
#  'death4',
#  'return4',
#  'death5',
#  'return5',
#  'notes']

# %%
new_columns[0] = "URL"
new_columns[3] = "is_current"
avengers.columns = new_columns

# %%
avengers["is_current"].value_counts()
# Out:
# is_current
# NO     91
# YES    82
# Name: count, dtype: int64

# %%
avengers.loc[:, "is_current"] = avengers["is_current"] == "YES"

# %%
avengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          173 non-null    object
#  1   name_alias                   163 non-null    object
#  2   appearances                  173 non-null    int64
#  3   is_current                   173 non-null    object
#  4   gender                       173 non-null    object
#  5   probationary_introl          15 non-null     object
#  6   full_reserve_avengers_intro  159 non-null    object
#  7   year                         173 non-null    int64
#  8   years_since_joining          173 non-null    int64
#  9   honorary                     173 non-null    object
#  10  death1                       173 non-null    object
#  11  return1                      69 non-null     object
#  12  death2                       17 non-null     object
#  13  return2                      16 non-null     object
#  14  death3                       2 non-null      object
#  15  return3                      2 non-null      object
#  16  death4                       1 non-null      object
#  17  return4                      1 non-null      object
#  18  death5                       1 non-null      object
#  19  return5                      1 non-null      object
#  20  notes                        75 non-null     object
# dtypes: int64(3), object(18)
# memory usage: 28.5+ KB

# %%
avengers.loc[:, "URL"] = avengers["URL"].str.strip()
avengers["URL"].str.startswith("http").sum(), avengers.shape
# Out:
# (173, (173, 21))

# %%
avengers.iloc[:, 0:10].describe(include="all")
# Out:
#                                                   URL      name_alias  \
# count                                             173             163
# unique                                            173             162
# top     http://marvel.wikia.com/Henry_Pym_(Earth-616)  Vance Astrovik
# freq                                                1               2
# mean                                              NaN             NaN
# std                                               NaN             NaN
# min                                               NaN             NaN
# 25%                                               NaN             NaN
# 50%                                               NaN             NaN
# 75%                                               NaN             NaN
# max                                               NaN             NaN
#
#         appearances is_current gender probationary_introl  \
# count    173.000000        173    173                  15
# unique          NaN          2      2                  12
# top             NaN      False   MALE              Jul-75
# freq            NaN         91    115                   2
# mean     414.052023        NaN    NaN                 NaN
# std      677.991950        NaN    NaN                 NaN
# min        2.000000        NaN    NaN                 NaN
# 25%       58.000000        NaN    NaN                 NaN
# 50%      132.000000        NaN    NaN                 NaN
# 75%      491.000000        NaN    NaN                 NaN
# max     4333.000000        NaN    NaN                 NaN
#
#        full_reserve_avengers_intro         year  years_since_joining honorary
# count                          159   173.000000           173.000000      173
# unique                          93          NaN                  NaN        4
# top                         Sep-63          NaN                  NaN     Full
# freq                             6          NaN                  NaN      138
# mean                           NaN  1988.445087            26.554913      NaN
# std                            NaN    30.374669            30.374669      NaN
# min                            NaN  1900.000000             0.000000      NaN
# 25%                            NaN  1979.000000             5.000000      NaN
# 50%                            NaN  1996.000000            19.000000      NaN
# 75%                            NaN  2010.000000            36.000000      NaN
# max                            NaN  2015.000000           115.000000      NaN

# %%
avengers.query("year < 1960")
# Out:
#                                                    URL       name_alias  \
# 75   http://marvel.wikia.com/Elvin_Haliday_(Earth-6...    Elvin Haliday
# 76   http://marvel.wikia.com/William_Baker_(Earth-6...    William Baker
# 122  http://marvel.wikia.com/James_Santini_(Earth-6...    James Santini
# 123  http://marvel.wikia.com/Emery_Schaub_(Earth-616)#     Emery Schaub
# 125  http://marvel.wikia.com/Fiona_(Inhuman)_(Earth...            Fiona
# 127        http://marvel.wikia.com/Hollow_(Earth-616)#           Yvette
# 128   http://marvel.wikia.com/Julie_Power_(Earth-616)#      Julie Power
# 129    http://marvel.wikia.com/Alani_Ryan_(Earth-616)#       Alani Ryan
# 132  http://marvel.wikia.com/Johnathon_Gallo_(Earth...     Johnny Gallo
# 133         http://marvel.wikia.com/Lyra_(Earth-8009)#             Lyra
# 134  http://marvel.wikia.com/Anya_Corazon_(Earth-616)#     Anya Corazon
# 136  http://marvel.wikia.com/Kevin_Masterson_(Earth...  Kevin Masterson
# 137  http://marvel.wikia.com/Michiko_Musashi_(Earth...  Michiko Musashi
# 138  http://marvel.wikia.com/Takashi_Matsuya_(Earth...     Taki Matsuya
#
#      appearances is_current  gender probationary_introl  \
# 75           158      False    MALE              Feb-91
# 76           355      False    MALE              Feb-91
# 122           40       True    MALE                 NaN
# 123           26       True    MALE                 NaN
# 125            2       True  FEMALE                 NaN
# 127           22       True  FEMALE                 NaN
# 128          153       True  FEMALE                 NaN
# 129           73       True  FEMALE                 NaN
# 132           43       True    MALE                 NaN
# 133           55       True  FEMALE                 NaN
# 134          108       True  FEMALE                 NaN
# 136           62       True    MALE                 NaN
# 137           94       True  FEMALE                 NaN
# 138           18       True    MALE                 NaN
#
#     full_reserve_avengers_intro  year  years_since_joining      honorary  ...  \
# 75                          NaN  1900                  115  Probationary  ...
# 76                          NaN  1900                  115  Probationary  ...
# 122                         NaN  1900                  115       Academy  ...
# 123                         NaN  1900                  115       Academy  ...
# 125                         NaN  1900                  115       Academy  ...
# 127                         NaN  1900                  115       Academy  ...
# 128                         NaN  1900                  115       Academy  ...
# 129                         NaN  1900                  115       Academy  ...
# 132                         NaN  1900                  115       Academy  ...
# 133                         NaN  1900                  115       Academy  ...
# 134                         NaN  1900                  115       Academy  ...
# 136                         NaN  1900                  115       Academy  ...
# 137                         NaN  1900                  115       Academy  ...
# 138                         NaN  1900                  115       Academy  ...
#
#     return1 death2 return2 death3 return3 death4 return4 death5 return5  \
# 75      NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 76      YES     NO     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 122     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 123     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 125     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 127     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 128     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 129     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 132     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 133     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 134     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 136     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 137     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 138     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
#                                                  notes
# 75                                                 NaN
# 76   Died in Identity_Disc_Vol_1_1. Later was revea...
# 122                                                NaN
# 123                                                NaN
# 125                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
#
# [14 rows x 21 columns]

# %% [markdown]
# There are no avengers introduced before 1960. Let us remove these 14 rows. Alternatively, we could impute "year" values from the web pages.

# %%
avengers = avengers.query("year >= 1960")

# %%
avengers.iloc[:, 10:].describe(include="all")
# Out:
#        death1 return1 death2 return2 death3 return3 death4 return4 death5  \
# count     159      68     16      16      2       2      1       1      1
# unique      2       2      1       2      1       2      1       1      1
# top        NO     YES    YES      NO    YES      NO    YES     YES    YES
# freq       91      45     16       8      2       1      1       1      1
#
#        return5                          notes
# count        1                             74
# unique       1                             70
# top        YES  Died in New_Avengers_Vol_3_32
# freq         1                              4

# %%
slice = avengers.iloc[:, 10:20]
slice
# Out:
#     death1 return1 death2 return2 death3 return3 death4 return4 death5 return5
# 0      YES      NO    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1      YES     YES    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2      YES     YES    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3      YES     YES    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4      YES     YES    YES      NO    NaN     NaN    NaN     NaN    NaN     NaN
# ..     ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 168     NO     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 169     NO     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 170     NO     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 171     NO     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 172     NO     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
# [159 rows x 10 columns]

# %% [markdown]
# We convert "death*" and "return*" values from "YES", "NO" to `True`, `False`.

# %%
slice[slice.notnull()] = False

# %%
slice
# Out:
#     death1 return1 death2 return2 death3 return3 death4 return4 death5 return5
# 0    False   False    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1    False   False    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2    False   False    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3    False   False    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4    False   False  False   False    NaN     NaN    NaN     NaN    NaN     NaN
# ..     ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 168  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 169  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 170  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 171  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 172  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
# [159 rows x 10 columns]

# %%
slice[avengers.iloc[:, 10:20] == "YES"] = True
slice
# Out:
#     death1 return1 death2 return2 death3 return3 death4 return4 death5 return5
# 0     True   False    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1     True    True    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2     True    True    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3     True    True    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4     True    True   True   False    NaN     NaN    NaN     NaN    NaN     NaN
# ..     ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 168  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 169  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 170  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 171  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 172  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
# [159 rows x 10 columns]

# %%
avengers.iloc[:, 10:20] = slice
avengers.iloc[:, 10:20]
# Out:
#     death1 return1 death2 return2 death3 return3 death4 return4 death5 return5
# 0     True   False    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1     True    True    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2     True    True    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3     True    True    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4     True    True   True   False    NaN     NaN    NaN     NaN    NaN     NaN
# ..     ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 168  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 169  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 170  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 171  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 172  False     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
# [159 rows x 10 columns]

# %% [markdown]
# There is a name which appears twice in "name_alias". We can fix it by looking at "URL".

# %%
print(avengers.query("name_alias == 'Vance Astrovik'")["URL"])
# Out:
# 28     http://marvel.wikia.com/Vance_Astro_(Earth-691)#
# 84    http://marvel.wikia.com/Vance_Astrovik_(Earth-...
# Name: URL, dtype: object

# %%
avengers.query("name_alias == 'Vance Astrovik'")
# Out:
#                                                   URL      name_alias  \
# 28   http://marvel.wikia.com/Vance_Astro_(Earth-691)#  Vance Astrovik
# 84  http://marvel.wikia.com/Vance_Astrovik_(Earth-...  Vance Astrovik
#
#     appearances is_current gender probationary_introl  \
# 28          156      False   MALE                 NaN
# 84          302      False   MALE                 NaN
#
#    full_reserve_avengers_intro  year  years_since_joining  honorary  ...  \
# 28                      Feb-78  1978                   37  Honorary  ...
# 84                      May-98  1998                   17      Full  ...
#
#    return1 death2 return2 death3 return3 death4 return4 death5 return5 notes
# 28     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
# 84     NaN    NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN   NaN
#
# [2 rows x 21 columns]

# %%
print(avengers.loc[28, "URL"])
# Out:
# http://marvel.wikia.com/Vance_Astro_(Earth-691)#

# %%
avengers.loc[28, "name_alias"] = "Vance Astro"
avengers["name_alias"].value_counts()
# Out:
# name_alias
# Henry Jonathan "Hank" Pym         1
# Thomas "Tommy" Shepherd           1
# Doctor Stephen Vincent Strange    1
# Ares                              1
# James Buchanan Barnes             1
#                                  ..
# Scott Edward Harris Lang          1
# Anthony Ludgate Druid             1
# Marrina Smallwood                 1
# Ravonna Lexus Renslayer           1
# Kaluu                             1
# Name: count, Length: 149, dtype: int64

# %%
avengers["appearances"].sort_values()
# Out:
# 39        2
# 68        3
# 65        4
# 117       6
# 67        7
#        ...
# 4      2402
# 2      3068
# 92     3130
# 6      3458
# 73     4333
# Name: appearances, Length: 159, dtype: int64

# %%
avengers.iloc[73]
# Out:
# URL                            http://marvel.wikia.com/Peter_Parker_(Earth-616)#
# name_alias                                                 Peter Benjamin Parker
# appearances                                                                 4333
# is_current                                                                  True
# gender                                                                      MALE
# probationary_introl                                                          NaN
# full_reserve_avengers_intro                                               Apr-90
# year                                                                        1990
# years_since_joining                                                           25
# honorary                                                                    Full
# death1                                                                      True
# return1                                                                     True
# death2                                                                      True
# return2                                                                     True
# death3                                                                       NaN
# return3                                                                      NaN
# death4                                                                       NaN
# return4                                                                      NaN
# death5                                                                       NaN
# return5                                                                      NaN
# notes                          Since joining the New Avengers: First death Ki...
# Name: 73, dtype: object

# %% [markdown]
# We also convert "probationary_introl" and "full_reserve_avengers_intro" into `datetime`.

# %%
name = "probationary_introl"
avengers.loc[:, name] = pd.to_datetime(avengers[name])
# Out:
# /var/folders/kj/trnztfjn67j9by8wztm_6y8m0000gn/T/ipykernel_20681/4228296204.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   avengers.loc[:, name] = pd.to_datetime(avengers[name])

# %%
name = "full_reserve_avengers_intro"
avengers[name].value_counts(dropna=False)
# Out:
# full_reserve_avengers_intro
# Sep-63    6
# 13-Feb    6
# 10-Aug    6
# Feb-78    6
# 10-May    6
#          ..
# May-93    1
# Jun-92    1
# Sep-92    1
# Apr-91    1
# 15-Jan    1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# We clean "full_reserve_avengers_intro" by extracting the name of the month, then combine with "year".

# %%
month = avengers[name].str.extract("([A-Z][a-z][a-z])")[0]
# Missing months are imputed by "Jan"
month[month.isnull()] = "Jan"
avengers[name + "2"] = month + "-" + avengers["year"].astype(str)

# %%
avengers.loc[:, name] = avengers[name + "2"]
avengers.drop(name + "2", axis=1, inplace=True)

# %%
avengers.loc[:, name] = pd.to_datetime(avengers[name])
# Out:
# /var/folders/kj/trnztfjn67j9by8wztm_6y8m0000gn/T/ipykernel_20681/3064626228.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   avengers.loc[:, name] = pd.to_datetime(avengers[name])

# %%
avengers[name].value_counts()
# Out:
# full_reserve_avengers_intro
# 1963-09-01    6
# 2013-02-01    6
# 2010-08-01    6
# 1978-02-01    6
# 2010-05-01    6
#              ..
# 1993-05-01    1
# 1992-06-01    1
# 1992-09-01    1
# 1991-04-01    1
# 2015-01-01    1
# Name: count, Length: 93, dtype: int64

# %%
avengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          159 non-null    object
#  1   name_alias                   149 non-null    object
#  2   appearances                  159 non-null    int64
#  3   is_current                   159 non-null    object
#  4   gender                       159 non-null    object
#  5   probationary_introl          13 non-null     object
#  6   full_reserve_avengers_intro  159 non-null    object
#  7   year                         159 non-null    int64
#  8   years_since_joining          159 non-null    int64
#  9   honorary                     159 non-null    object
#  10  death1                       159 non-null    object
#  11  return1                      68 non-null     object
#  12  death2                       16 non-null     object
#  13  return2                      16 non-null     object
#  14  death3                       2 non-null      object
#  15  return3                      2 non-null      object
#  16  death4                       1 non-null      object
#  17  return4                      1 non-null      object
#  18  death5                       1 non-null      object
#  19  return5                      1 non-null      object
#  20  notes                        74 non-null     object
# dtypes: int64(3), object(18)
# memory usage: 31.4+ KB

# %%
(avengers["year"] + avengers["years_since_joining"] == 2015).sum()
# Out:
# 159

# %% [markdown]
# Finally, we can fill in missing "name_alias" values from the URLs.

# %%
avengers.loc[avengers["name_alias"].isnull(), "URL"]
# Out:
# 56        http://marvel.wikia.com/Gilgamesh_(Earth-616)#
# 61       http://marvel.wikia.com/Dinah_Soar_(Earth-616)#
# 67       http://marvel.wikia.com/Monkey_Joe_(Earth-616)#
# 69        http://marvel.wikia.com/Tippy-Toe_(Earth-616)#
# 80     http://marvel.wikia.com/Melissa_Darrow_(Earth-...
# 81         http://marvel.wikia.com/Deathcry_(Earth-616)#
# 148    http://marvel.wikia.com/Captain_Universe_(Eart...
# 153       http://marvel.wikia.com/Ex_Nihilo_(Earth-616)#
# 154    http://marvel.wikia.com/Abyss_(Ex_Nihilo%27s)_...
# 166    http://marvel.wikia.com/Doombot_(Avenger)_(Ear...
# Name: URL, dtype: object

# %%
pattern = r"^http://marvel.wikia.com/([\w-]+)_\("
nm_null = avengers["name_alias"].isnull()
new_names = avengers.loc[avengers["name_alias"].isnull(), "URL"].str.extract(pattern)[0].str.replace("[_-]", " ", regex=True)
avengers.loc[nm_null, "name_alias"] = new_names

# %% [markdown]
# Let us check for consistency between "URL" and "name_alias" in general.

# %%
all_names = avengers["URL"].str.extract(pattern)[0].str.replace("[_-]", " ", regex=True)
diff_ind = all_names != avengers["name_alias"]
avengers.loc[diff_ind, ["URL", "name_alias"]]
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 5    http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 7     http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 11        http://marvel.wikia.com/Hercules_(Earth-616)
# ..                                                 ...
# 149   http://marvel.wikia.com/Isabel_Kane_(Earth-616)#
# 151  http://marvel.wikia.com/Rogue_(Anna_Marie)_(Ea...
# 155     http://marvel.wikia.com/Nightmask_(Earth-616)#
# 156  http://marvel.wikia.com/Kevin_Connor_(Earth-616)#
# 161  http://marvel.wikia.com/Nicholas_Fury,_Jr._(Ea...
#
#                              name_alias
# 0             Henry Jonathan "Hank" Pym
# 2           Anthony Edward "Tony" Stark
# 5                Richard Milhouse Jones
# 7                Clinton Francis Barton
# 11                             Heracles
# ..                                  ...
# 149                           Izzy Kane
# 151                          Anna Marie
# 155                                Adam
# 156                   Kevin Kale Connor
# 161  Nicholas Fury, Jr., Marcus Johnson
#
# [66 rows x 2 columns]

# %%
avengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL                          159 non-null    object
#  1   name_alias                   159 non-null    object
#  2   appearances                  159 non-null    int64
#  3   is_current                   159 non-null    object
#  4   gender                       159 non-null    object
#  5   probationary_introl          13 non-null     object
#  6   full_reserve_avengers_intro  159 non-null    object
#  7   year                         159 non-null    int64
#  8   years_since_joining          159 non-null    int64
#  9   honorary                     159 non-null    object
#  10  death1                       159 non-null    object
#  11  return1                      68 non-null     object
#  12  death2                       16 non-null     object
#  13  return2                      16 non-null     object
#  14  death3                       2 non-null      object
#  15  return3                      2 non-null      object
#  16  death4                       1 non-null      object
#  17  return4                      1 non-null      object
#  18  death5                       1 non-null      object
#  19  return5                      1 non-null      object
#  20  notes                        74 non-null     object
# dtypes: int64(3), object(18)
# memory usage: 31.4+ KB

# %% [markdown]
# This is all we can do. The information encoded by "death*", "return*" is clunky: we could use a single string or list column with the same information.

# %%
names = [x for x in avengers.columns if x.startswith("death")]
avengers["num_deaths"] = avengers[names].sum(axis=1).astype(int)
avengers["num_deaths"].value_counts(dropna=False)
# Out:
# num_deaths
# 0    91
# 1    52
# 2    14
# 3     1
# 5     1
# Name: count, dtype: int64

# %%
avengers[names + ["num_deaths"]]
# Out:
#     death1 death2 death3 death4 death5  num_deaths
# 0     True    NaN    NaN    NaN    NaN           1
# 1     True    NaN    NaN    NaN    NaN           1
# 2     True    NaN    NaN    NaN    NaN           1
# 3     True    NaN    NaN    NaN    NaN           1
# 4     True   True    NaN    NaN    NaN           2
# ..     ...    ...    ...    ...    ...         ...
# 168  False    NaN    NaN    NaN    NaN           0
# 169  False    NaN    NaN    NaN    NaN           0
# 170  False    NaN    NaN    NaN    NaN           0
# 171  False    NaN    NaN    NaN    NaN           0
# 172  False    NaN    NaN    NaN    NaN           0
#
# [159 rows x 6 columns]

# %%
avengers.to_csv(data_path / "avengers_cleaned.csv")
